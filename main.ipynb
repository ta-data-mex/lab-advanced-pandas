# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('../Admission_Predict.csv')
admissions
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip() #cosa de este lab, no visto en otros
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# 5             6        321          109                  3  3.0  4.0  8.20
# 6             7        308          101                  2  3.0  4.0  7.90
# 7             8        302          102                  1  2.0  1.5  8.00
# 8             9        323          108                  3  3.5  3.0  8.60
# 9            10        327          111                  4  4.0  4.5  9.00
# 10           11        328          112                  4  4.0  4.5  9.10
# ...

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
admissions.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions.index = admissions['Serial No.']
admissions.head()
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.00         1             0.72
# 3           8.67         1             0.80
# 4           8.21         0             0.65
# 5           9.34         1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
admissions.index = admissions['GRE Score']
admissions.sort_index()
#observamos que hay al menos dos estudiantes con el mismo GRE Score por lo que no es un índice único
#ejemplos 290 y 294
# Out:
#            Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# GRE Score
# 290               113        290          104                  4  2.0  2.5
# 290               363        290          100                  1  1.5  2.0
# 293               162        293           97                  2  2.0  4.0
# 294               260        294           95                  1  1.5  1.5
# 294                76        294           93                  1  1.5  2.0
# 295                25        295           93                  1  2.0  2.0
# 295               330        295           96                  2  1.5  2.0
# 295               314        295          101                  2  2.5  2.0
# 295               196        295           99                  2  2.5  3.0
# 296               374        296           97                  2  1.5  2.0
# 296               215        296           99                  2  2.5  2.5
# ...

# %%
admissions.index = admissions['CGPA']
admissions.sort_index()
#CGPA tampoco sirve como índice poruqe hay al menos dos personas con el mismo CGPA de 7.34
# Out:
#       Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# CGPA
# 6.80          55        300           99                  1  3.0  2.0  6.80
# 7.20          25        295           93                  1  2.0  2.0  7.20
# 7.25         334        302           99                  1  2.0  2.0  7.25
# 7.28         114        296           99                  2  3.0  3.5  7.28
# 7.30          26        310           99                  2  1.5  2.0  7.30
# 7.34         330        295           96                  2  1.5  2.0  7.34
# 7.34         333        299           94                  1  1.0  1.0  7.34
# 7.36          76        294           93                  1  1.5  2.0  7.36
# 7.40          53        316          102                  3  2.0  3.0  7.40
# 7.43         362        297           96                  2  2.5  2.0  7.43
# 7.43         331        316           98                  1  1.5  2.0  7.43
# ...

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
admin2 = admissions.set_index(["GRE Score", "CGPA"]) #solito el set_index las quita del df principal
admin2.sort_index() #Consideramos que así sirve bastante para clasificar a los estudiantes
#pero debido a que si crece demasiado el número de estudiantes sube la probabilidad de que haya las 
#mismas parejas y haya conflicto con los registros no recomendamos identificar de esta manera
# Out:
#                 Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# GRE Score CGPA
# 290       7.46         113          104                  4  2.0  2.5
#           7.56         363          100                  1  1.5  2.0
# 293       7.80         162           97                  2  2.0  4.0
# 294       7.36          76           93                  1  1.5  2.0
#           7.64         260           95                  1  1.5  1.5
# 295       7.20          25           93                  1  2.0  2.0
#           7.34         330           96                  2  1.5  2.0
#           7.65         196           99                  2  2.5  3.0
#           7.86         314          101                  2  2.5  2.0
# 296       7.28         114           99                  2  3.0  3.5
#           7.54          75           95                  2  3.0  2.0
#           7.68         229          101                  1  2.5  3.0
# ...

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:
admissions[(admissions.CGPA > 9) & (admissions.Research == 1)] #101 registros
# Out:
#       Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# CGPA
# 9.65           1        337          118                  4  4.5  4.5  9.65
# 9.34           5        330          115                  5  4.5  3.0  9.34
# 9.10          11        328          112                  4  4.0  4.5  9.10
# 9.50          20        328          116                  5  5.0  5.0  9.50
# 9.70          21        334          119                  5  5.0  4.5  9.70
# 9.80          22        336          119                  5  4.0  3.5  9.80
# 9.40          29        338          118                  4  3.0  4.5  9.40
# 9.60          30        340          114                  5  4.0  4.0  9.60
# 9.80          31        331          112                  5  4.0  5.0  9.80
# 9.20          32        320          110                  5  5.0  5.0  9.20
# 9.40          41        326          113                  5  4.5  4.0  9.40
# ...

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:
#En una linea
admissions[(admissions.CGPA > 9) & (admissions.SOP < 3.5)]['Chance of Admit'].mean()

#Por pasos
admin1 = admissions[(admissions.CGPA > 9) & (admissions.SOP < 3.5)]
admin1['Chance of Admit'].mean() #0.8019
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    
    # Your code here:
    column_mean = np.mean(col)
    column_std = np.std(col)
    standarized_column = np.absolute(col - column_mean)/column_std 
    return standarized_column

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
#Este pedazo es para obtener datos que verifiquen que la función de arriba si funciona bien
CGPA_mean = admissions['CGPA'].mean() #8.597090909090909
CGPA_std = admissions['CGPA'].std() #0.6023853232371412
print(CGPA_mean,CGPA_std)


admissions['CGPA_std'] = standardize(admissions.CGPA)
admissions['GRE_std'] = standardize(admissions['GRE Score'])
admissions['LOR_std'] = standardize(admissions.LOR)
admissions.head()
# Out:
# 8.597090909090909 0.6023853232371412
#       Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# CGPA
# 9.65           1        337          118                  4  4.5  4.5  9.65
# 8.00           2        316          104                  3  3.0  3.5  8.00
# 8.67           3        322          110                  3  3.5  2.5  8.67
# 8.21           4        314          103                  2  2.0  3.0  8.21
# 9.34           5        330          115                  5  4.5  3.0  9.34
#
#       Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# CGPA
# 9.65         1             0.92  1.750174  1.755663  1.193197
# 8.00         1             0.72  0.992501  0.063450  0.076840
# 8.67         1             0.80  0.121191  0.456297  1.039517
# 8.21         0             0.65  0.643433  0.236698  0.481338
# 9.34         1             0.90  1.234884  1.149292  0.481338

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0]) #es una lista
#decision_choice

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:
admissions['deciding_column'] = admissions.lookup(admissions.index, decision_choice)
#df.lookup(row labels, column labels)
admissions.deciding_column
# Out:
# CGPA
# 9.65                                              1.75017
# 8.00    [0.06344955097704703, 1.2761909685879955, 0.84...
# 8.67    [0.45629677085621656, 0.10979922296737417, 0.5...
# 8.21            [0.23669832492146825, 0.7564446467547319]
# 9.34               [0.48133840104963, 1.1931973013971253]
# 8.20    [0.6600552885787807, 0.6600552885787807, 0.660...
# 7.90    [1.1587234324226374, 1.1587234324226374, 1.158...
# 8.00    [0.9925007178080185, 0.9925007178080185, 0.992...
# 8.60             [0.5429211578284272, 0.7564446467547319]
# 9.00    [0.6697264283381763, 0.6697264283381763, 0.669...
# 9.10    [0.8359491429527952, 0.8359491429527952, 0.835...
# 8.00    [0.07684016643262176, 2.155874103496385, 0.481...
# 8.20    [0.6600552885787807, 0.6600552885787807, 0.660...
# 8.30    [1.0395169685318817, 0.6350187339148735, 1.193...
# 8.70              [0.48133840104963, 0.07684016643262176]
# 8.00    [0.07684016643262176, 2.155874103496385, 0.481...
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:
admissions['decision'] = np.where ...

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:
