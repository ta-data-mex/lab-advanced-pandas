# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
admissions.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:

admissions.set_index(admissions['Serial No.'], inplace=True)

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
admissions['gre_gpa'] = admissions['GRE Score'].apply(lambda x:str(x)) + admissions['CGPA'].apply(lambda x: str(x))

# %%
len(admissions['gre_gpa'].unique()) == len(admissions['Serial No.'])
# Out:
# True

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
admissions.set_index(['Serial No.', 'GRE Score', 'CGPA'], inplace=True)

# %%
admissions.drop(columns = 'gre_gpa', inplace=True)

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:

admissions.reset_index(inplace=True)

# %%
admissions.head()
# Out:
#    Serial No.  GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# 0           1        337  9.65          118                  4  4.5  4.5
# 1           2        316  8.00          104                  3  3.0  3.5
# 2           3        322  8.67          110                  3  3.5  2.5
# 3           4        314  8.21          103                  2  2.0  3.0
# 4           5        330  9.34          115                  5  4.5  3.0
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:
admissions[(admissions['CGPA']>9) & (admissions['Research']==1)]
# Out:
#      Serial No.  GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# 0             1        337  9.65          118                  4  4.5  4.5
# 4             5        330  9.34          115                  5  4.5  3.0
# 10           11        328  9.10          112                  4  4.0  4.5
# 19           20        328  9.50          116                  5  5.0  5.0
# 20           21        334  9.70          119                  5  5.0  4.5
# 21           22        336  9.80          119                  5  4.0  3.5
# 28           29        338  9.40          118                  4  3.0  4.5
# 29           30        340  9.60          114                  5  4.0  4.0
# 30           31        331  9.80          112                  5  4.0  5.0
# 31           32        320  9.20          110                  5  5.0  5.0
# 40           41        326  9.40          113                  5  4.5  4.0
# 41           42        322  9.10          110                  5  5.0  4.0
# 42           43        329  9.30          114                  5  4.0  5.0
# 64           65        318  9.22          109                  3  3.5  4.0
# 65           66        328  9.16          115                  4  4.5  4.0
# 66           67        332  9.64          118                  5  5.0  5.0
# 67           68        336  9.76          112                  5  5.0  5.0
# 68           69        321  9.45          111                  5  5.0  5.0
# 69           70        314  9.04          108                  4  4.5  4.0
# 77           78        340  9.50          120                  4  5.0  5.0
# 78           79        320  9.22          110                  5  5.0  4.5
# 79           80        322  9.36          115                  5  4.0  4.5
# 80           81        340  9.45          115                  5  4.5  4.5
# 93           94        332  9.24          119                  4  5.0  4.5
# 99          100        326  9.05          112                  3  3.5  3.0
# 101         102        329  9.18          111                  4  4.5  4.5
# 102         103        338  9.46          117                  4  3.5  4.5
# 103         104        331  9.38          116                  5  5.0  5.0
# 110         111        310  9.04          106                  4  4.5  4.5
# 115         116        335  9.56          117                  5  5.0  5.0
# ..          ...        ...   ...          ...                ...  ...  ...
# 231         232        325  9.04          114                  3  3.5  3.0
# 233         234        328  9.02          110                  4  4.0  2.5
# 241         242        335  9.68          115                  4  4.5  4.5
# 246         247        331  9.34          119                  4  5.0  4.5
# 247         248        327  9.13          108                  5  5.0  3.5
# 263         264        329  9.45          113                  5  5.0  4.5
# 268         269        317  9.11          110                  3  4.0  4.5
# 271         272        340  9.66          112                  4  5.0  4.5
# 272         273        331  9.26          116                  5  4.0  4.0
# 273         274        336  9.19          118                  5  4.5  4.0
# 274         275        324  9.08          114                  5  5.0  4.5
# 285         286        330  9.24          114                  3  4.5  4.5
# 293         294        323  9.10          110                  3  4.0  3.5
# 298         299        328  9.18          108                  4  4.5  4.0
# 311         312        326  9.14          116                  3  3.5  4.0
# 322         323        332  9.47          118                  5  5.0  5.0
# 346         347        334  9.54          116                  4  4.0  3.5
# 347         348        338  9.23          115                  5  4.5  5.0
# 350         351        330  9.17          114                  4  4.5  3.0
# 356         357        324  9.22          110                  3  3.5  3.0
# 357         358        336  9.62          119                  4  4.5  4.0
# 367         368        324  9.15          110                  4  4.5  4.0
# 369         370        340  9.74          113                  4  5.0  5.0
# 370         371        335  9.82          117                  5  5.0  5.0
# 377         378        326  9.12          112                  4  4.0  3.5
# 379         380        329  9.23          111                  4  4.5  4.0
# 380         381        324  9.04          110                  3  3.5  3.5
# 381         382        325  9.11          107                  3  3.0  3.5
# 382         383        330  9.45          116                  4  5.0  4.5
# 384         385        333  9.66          117                  4  5.0  4.0
#
#      Research  Chance of Admit
# 0           1             0.92
# 4           1             0.90
# 10          1             0.78
# 19          1             0.94
# 20          1             0.95
# 21          1             0.97
# 28          1             0.91
# 29          1             0.90
# 30          1             0.94
# 31          1             0.88
# 40          1             0.91
# 41          1             0.88
# 42          1             0.86
# 64          1             0.68
# 65          1             0.78
# 66          1             0.94
# 67          1             0.96
# 68          1             0.93
# 69          1             0.84
# 77          1             0.96
# 78          1             0.92
# 79          1             0.92
# 80          1             0.94
# 93          1             0.90
# 99          1             0.74
# 101         1             0.87
# 102         1             0.91
# 103         1             0.93
# 110         1             0.66
# 115         1             0.94
# ..        ...              ...
# 231         1             0.76
# 233         1             0.81
# 241         1             0.93
# 246         1             0.90
# 247         1             0.87
# 263         1             0.89
# 268         1             0.80
# 271         1             0.94
# 272         1             0.93
# 273         1             0.92
# 274         1             0.89
# 285         1             0.90
# 293         1             0.79
# 298         1             0.84
# 311         1             0.81
# 322         1             0.94
# 346         1             0.93
# 347         1             0.91
# 350         1             0.86
# 356         1             0.89
# 357         1             0.95
# 367         1             0.82
# 369         1             0.96
# 370         1             0.96
# 377         1             0.84
# 379         1             0.89
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 384         1             0.95
#
# [101 rows x 9 columns]

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
admissions[(admissions['CGPA']>9) & (admissions['SOP']<3.5)]
# Out:
#      Serial No.  GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# 28           29        338  9.40          118                  4  3.0  4.5
# 62           63        327  9.02          114                  3  3.0  3.0
# 140         141        326  9.11          114                  3  3.0  3.0
# 217         218        324  9.01          111                  4  3.0  3.0
# 381         382        325  9.11          107                  3  3.0  3.5
#
#      Research  Chance of Admit
# 28          1             0.91
# 62          0             0.61
# 140         1             0.83
# 217         1             0.82
# 381         1             0.84

# %%
# Your code here:

admissions[(admissions['CGPA']>9) & (admissions['SOP']<3.5)]['Chance of Admit'].mean()
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    std = [((i - np.mean(col))/ np.std(col)) for i in col]
    return std
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    # Your code here:

# %%
admissions['CGPA_std'] = standardize(admissions['CGPA'])

# %%
admissions['GRE_std'] = standardize(admissions['GRE Score'])
admissions['LOR_std'] = standardize(admissions['LOR'])

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:

admissions['deciding_column'] = admissions.lookup(admissions.index,decision_choice)

# %%
admissions.head()
# Out:
#    Serial No.  GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# 0           1        337  9.65          118                  4  4.5  4.5
# 1           2        316  8.00          104                  3  3.0  3.5
# 2           3        322  8.67          110                  3  3.5  2.5
# 3           4        314  8.21          103                  2  2.0  3.0
# 4           5        330  9.34          115                  5  4.5  3.0
#
#    Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column
# 0         1             0.92  1.750174  1.755663  1.193197         1.193197
# 1         1             0.72 -0.992501 -0.063450  0.076840         0.076840
# 2         1             0.80  0.121191  0.456297 -1.039517        -1.039517
# 3         0             0.65 -0.643433 -0.236698 -0.481338        -0.236698
# 4         1             0.90  1.234884  1.149292 -0.481338         1.234884

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:

admissions['decision'] = np.where(admissions['deciding_column']>0.8, 1, 0)

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:

admissions['decision'].value_counts()
# Out:
# 0    294
# 1     91
# Name: decision, dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:

admissions.columns = [i.replace('.','').lower().replace(' ', '_') for i in list(admissions.columns)]

# %%
admissions.head(1)
# Out:
#    serial_no  gre_score  cgpa  toefl_score  university_rating  sop  lor  \
# 0          1        337  9.65          118                  4  4.5  4.5
#
#    research  chance_of_admit  cgpa_std   gre_std   lor_std  deciding_column  \
# 0         1             0.92  1.750174  1.755663  1.193197         1.193197
#
#    decision
# 0         1

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:


admissions['adjusted_gre'] = admissions['gre_score']
mask = admissions.university_rating >=4
admissions.loc[mask, 'adjusted_gre'] += 10

# %%
admissions['adjusted_gre'] = pd.cut(admissions['adjusted_gre'], 4)

# %%
admissions.head()
# Out:
#    serial_no  gre_score  cgpa  toefl_score  university_rating  sop  lor  \
# 0          1        337  9.65          118                  4  4.5  4.5
# 1          2        316  8.00          104                  3  3.0  3.5
# 2          3        322  8.67          110                  3  3.5  2.5
# 3          4        314  8.21          103                  2  2.0  3.0
# 4          5        330  9.34          115                  5  4.5  3.0
#
#    research  chance_of_admit  cgpa_std   gre_std   lor_std  deciding_column  \
# 0         1             0.92  1.750174  1.755663  1.193197         1.193197
# 1         1             0.72 -0.992501 -0.063450  0.076840         0.076840
# 2         1             0.80  0.121191  0.456297 -1.039517        -1.039517
# 3         0             0.65 -0.643433 -0.236698 -0.481338        -0.236698
# 4         1             0.90  1.234884  1.149292 -0.481338         1.234884
#
#    decision    adjusted_gre
# 0         1  (335.0, 350.0]
# 1         0  (305.0, 320.0]
# 2         0  (320.0, 335.0]
# 3         0  (305.0, 320.0]
# 4         1  (335.0, 350.0]
